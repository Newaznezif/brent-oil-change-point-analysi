# %%
import pandas as pd

# Load your result file
cp_path = '../data/processed/change_points_results.csv'
df = pd.read_csv(cp_path)

# If your column is 'metric' and 'value', we need to reshape it for the dashboard
# The dashboard expects a row with a 'change_date' column
new_data = {
    'change_date': ['2011-10-04'],
    'volatility_before': [1.2821],
    'volatility_after': [1.6903],
    'impact': ['31.84%']
}
df_aligned = pd.DataFrame(new_data)
df_aligned.to_csv(cp_path, index=False)

print("✅ Aligned change_points_results.csv with Dashboard requirements.")
# Out:
# ✅ Aligned change_points_results.csv with Dashboard requirements.
